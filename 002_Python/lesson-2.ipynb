# %%
list1= ["apple",1,3.5,True, [1,3], {"Ready" : "yes"} ]

# %%
list_of_names= []
type(list_of_names)
# Out:
# list

# %%
my_list = list()
type(my_list)
# Out:
# list

# %%
my_list2=list("January")
my_list2
# Out:
# ['J', 'a', 'n', 'u', 'a', 'r', 'y']

# %%
my_num_list = list((1,2,3)) # list type i 1 argument alir burada herbir sayiyi 1 argument olarak degerlendirip 3 arg saniyor o yuzden bir parantez icine daha almak gerekiyor
my_num_list

my_num_list = list((123,)) # (123) seklinde yazarsak bir tuple olusturmus oluyoruz o yuzden hata verir sonuna , eklemek gerekiyor

# %%
my_num_list
# Out:
# [123]

# %%
my_num_list.append([4,5]) #mutable old icin uzerine ekleyerek gidebiliyor
my_num_list
# Out:
# [123, 33, [4, 5]]

# %%
my_num_list.clear()
my_num_list
# Out:
# []

# %%
list1 =[1,2]
list2 = [3,4] 
list1 + list2 # seklinde 2 listeyi birbirine ekleyebiliyoruz
# Out:
# [1, 2, 3, 4]

# %%
list1.append(list2)
list1 # seklinde old gibi diger listeyi ekleme de yapabiliyor
# Out:
# [1, 2, [3, 4]]

# %%
list1.extend(list2)
list1 #extend append gibi metodlar listeyi kalici olarak degistiriyor
# Out:
# [1, 2, [3, 4], 3, 4]

# %%
list1  = list2

# %%
print(list1)
print(list2) #yukarida esitledikten sonra list 1 de 2 gibi oldu
# Out:
# [3, 4]
# [3, 4]

# %%
print(id(list1))
print(id(list2)) #eger id built in fonk ile id lerine bakarsak ikisininde ayni obje old göruyoruz
# Out:
# 2044793319616
# 2044793319616

# %%
list1.append(5)

# %%
list2 # eger list 1 e eleman ekleyip list2 yi göruntulersek ikiside ayni object old icin eklemeyi 2 ye de yapiyor
# Out:
# [3, 4, 5]

# %%
# eger list2 orjinal kalsin bnde kopyalayip onun uzerinde degisiklik yapmak istersem

list1 = []
list1 = [3,4]

# %%
list1= list2.copy() # kopylama islemini bu seklde yapiyoruz
list1
# Out:
# [3, 4, 5]

# %%
list1.count(3)
# Out:
# 1

# %%
list1.count(6) #count icine bir deger aliyor ve var olmasina göre return ediyor
# Out:
# 0

# %%
list1.index(3) # value nin index ine bakmak icin kull. eger olmayan bir degerse hata veriyor
# Out:
# 0

# %%
list1.insert(0,5) # append ile sonuna ekleme yapiyoruz ve list1 cagirdigmizda bir daha ekliyor  istedigimiz yere ekleme yapmak icin insert  kul ve ilk parametre nereye ekleyecegimiz 2. ise ne ekleyecegimiz

# %%
list1
# Out:
# [5, 3, 4, 5]

# %%
list1.pop() # son elemani return ediyor eger icine parametre verirsek onu da index num olarak degerlendirip cikarma yapip return yapiyor
# Out:
# 5

# %%
list1
# Out:
# [5, 3, 4]

# %%
list1.pop(1)
# Out:
# 3

# %%
list1
# Out:
# [5, 4]

# %%
list1.remove(5) # remove bir value aliyor ve o degeri cikariyor

# %%
list1
# Out:
# [4]

# %%
list2= list('Python')
list2
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
list2.reverse()
list2
# Out:
# ['n', 'o', 'h', 't', 'y', 'P']

# %%
list2.sort()
list2 # sort alfabetik olarak ascii ye göre siralama yapiyor
# Out:
# ['P', 'h', 'n', 'o', 't', 'y']

# %%
my_list= ["apple",1,3.5,True, [1,3], {"Ready" : "yes"} ]
my_list[3] #3.index e gider
# Out:
# True

# %%
my_list[4] #4. indexdeki 2. sayiya gitmek icin
# Out:
# [1, 3]

# %%
my_list[4][1]
# Out:
# 3

# %%
list1=["a","b","c"]
list2=[1,2,3] #yazip kod blogunu calistirinca list1 ve 2 degerleri guncelleniyor

# %%
list1 += list2 #concatanate yapiyor

# %%
list1
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
#*********************** TUPLE ************************

# %%
my_tuple = ()
type(my_tuple) #bos () tuple olusturmak icin yeterli
# Out:
# tuple

# %%
my_tuple = ("a",) # tek eleman sonuna , koymassak string oluyor , ile tuple oluyor

# %%
tuple1 = ( "abc",34,True,40,"male",40) #tuple birden fazla data type barindirabilir ve ayni eleman da birden fazla olabilir

tuple1[4] # index ine yine bu sekilde ulasabilirz

# tuple larda 2 tane method var cunku degistirilemez olduklari icin
# Out:
# 'male'

# %%
tuple1.count(40) #olmayan bir eleman aranirsa 0 döner
# Out:
# 2

# %%
tuple1.index(True) # aradigmiz elemanin index no su döner olmayan bir elemanda ise hata verir
# Out:
# 2

# %%
tuple1.index(40,4) # 2 parametre yazarsak ilk i degerin old index ustune bir daha verilen deger var mi diye 2.verilen degeri baslangic indexi olarak alip onun uzerine arama yapiyor

# sabit olacak ve sonradan degistirilmeyecek degerler icin tuple kullanilabilir
# Out:
# 5

# %%
thisdict = {
    "brand":"Ford",
    "model": "Mustang",
    "year":1964
}

# dictionary bir obje diger python elemanlari gibi ve key-value ciftlerinden olusuyor ve index numarasi ile ulasmamiza gerek yok []actigimizda aramak istedigimiz keyler cikiyor

thisdict["year"]
# Out:
# 1964

# %%
thisdict.get('yea') # eger [] icinde key i yanlis yazarsak hata veriyor fakat get metodu ile olmayan bir key aradigimizda hicbir sey döndurmuyor hataya da sebep olmuyor

# %%
thisdict.get('yea',"this argument doesn't exist") # default olarak bir error mesaji ekleyebliyoruz 2.yazdigmiz err mssg oluyor
# Out:
# "this argument doesn't exist"

# %%
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict["year"] = 2023 #var olan degeri bu sekilde degistirebiliyoruz
thisdict
# Out:
# {'model': 'Mustang', 'year': 2023, 'color': 'red'}

# %%
thisdict.update({"year":1964, 'color':"red","brand": "Ford2"}) #update met ile degerleri degstrbliyoruz ve istersek yeni bir key-value cifti de ekleyebiliyoruz
thisdict
# Out:
# {'model': 'Mustang', 'year': 1964, 'color': 'red', 'brand': 'Ford2'}

# %%
thisdict.pop('brand') #pop metodunu bos olarak kullanirsak hata veriyor icine en az bir arg almasi gerekiyor, cikarmak istdegimiz key i yaziyoruz ve icine mesaj da ekleyebiliyoruz 
thisdict
# Out:
# {'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %%
del thisdict ["color"] #del metodu da silme islemi icin kullanilabiliyor ve icine key almasi gerekiyor yada del ile olusturdugumuz objeyi oldugu gibi silebiliriz
thisdict
# Out:
# {'model': 'Mustang', 'year': 1964}

# %%
thisdict.update({"brand":"Ford"})
thisdict
# Out:
# {'model': 'Mustang', 'year': 1964, 'brand': 'Ford'}

# %%
thisdict.keys() #sadece key leri return eder
# Out:
# dict_keys(['model', 'year', 'brand'])

# %%
thisdict.values() # sadece velue lari return eder
# Out:
# dict_values(['Mustang', 1964, 'Ford'])

# %%
thisdict.items() #objeyi tuple olarak return eder
# Out:
# dict_items([('model', 'Mustang'), ('year', 1964), ('brand', 'Ford')])

# %%
# set metodu eger list ve tuple varsa ve karsilastirmak istiyorsak list ile yapamiyoruz set ile yapabiliyoruz set yaptigimizda ayni elemanlar gider farkli olanlar kalir bu sekilde ayni olanlari yada farkli olan elemanlari bulabiliriz

my_set = {"apple",1,2,3} #bos {} old dict döner bos oldugunda construct edemiyoruz o yuzden bos olmasi yeterli degil, icini doldurdugumuzda set e dönusur, key value seklinde olusturmadigimiz icin direk set olarak algiliyor
type(my_set)
# Out:
# set

# %%
my_new_set = set() #eger bos set olusturmak istersek bu sekilde yazmamiz gerekiyor
type(my_new_set)
# Out:
# set

# %%
my_new_set
# Out:
# set()

# %%
thisset = {'apple','banana','cherry'}
thisset.add('orange') #add ile ekleme yapblryz
thisset
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %%
thisset.remove("apple") # remove ile cikarma yapabiliyorz ager yazdigimiz eleman yok ise hata veriyor hata vermemesi icin discard kullaniyoruz 
thisset
# Out:
# {'banana', 'cherry', 'orange'}

# %%
thisset.discard("app") #yanina hata mesaji yapmiyoruz 
thisset
# Out:
# {'banana', 'cherry', 'orange'}

# %%
a= {1,2,3,10,32,100}
b={1,2,32}

a.difference(b) #farkini bulmak icin
# Out:
# {3, 10, 100}

# %%
a.intersection(b) #ortak olanlari return eder
# Out:
# {1, 2, 32}

# %%
a.union(b) #birlestirme yapiyor ve a yi degistiriyor | isareti ile de yapabiliyoruz o da a yi degistiriyor, eger bir list varsa ve ayni eleman birden fazla kullanilmissa set e cevirip ayni elemanlari kaldirabiliriz
# Out:
# {1, 2, 3, 10, 32, 100}
