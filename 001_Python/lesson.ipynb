# %%
# This line prints a hello world
print("Hello World!")#comment line
# Out:
# Hello World!

# %%
my_var = "Hello World!"
my_num = 12

print(type(my_var))
print(type(my_num))
# Out:
# <class 'str'>
# <class 'int'>

# %%
first_name='Rafe'

# %%
greeting="Hello Python! 1234"
print(greeting)
# Out:
# Hello Python! 1234

# %%
last_name="demir"

last_name[0:4:2]
last_name[2:]
last_name[::-1]
last_name.upper()
# Out:
# 'DEMIR'

# %%
my_new_var = "Edip Edirnede pide ye"

my_new_var.count("e")
my_new_var.lower().count("e")
my_new_var.split()
my_new_var.lower().split()
my_new_var.replace("Edirne","Izmir")
my_new_var.startswith("a")
# Out:
# False

# %%
my_new_var = "Edip Edirnede pide yessssssssssssss"

my_new_var.strip("s")
my_new_var.index("d")
# Out:
# 1

# %%
my_int = 15

# %%
my_int + 10
# Out:
# 25

# %%
7%2
# Out:
# 1

# %%
money_spent = 15.50
print(type(money_spent))
# Out:
# <class 'float'>

# %%
first_name="Yasin"
age=30

print(f"my name is {first_name}")
print(f"my name is {first_name}, i am {age} years old")
# Out:
# my name is Yasin
# my name is Yasin, i am 30 years old

# %%
isik_acik = True

# %%
if isik_acik:
    print("isiklari kapatiniz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 if isik_acik:
#       2     print("isiklari kapatiniz")
#
# NameError: name 'isik_acik' is not defined

# %%
sayi_1 = 3
sayi_2 = 5

sayi_1<= sayi_2
# Out:
# True

# %%
my_string="Some characters"
my_int =12

# %%
print(type(my_int))
my_int = str(my_int)
print(type(my_int))
# Out:
# <class 'int'>
# <class 'str'>
